# %% [markdown]
# # 1 · Quickstart
#
# **roadstyle** turns a GeoDataFrame of roads into a styled, interactive map — an OSM-style *geometry sandwich* (a coloured fill over a wider casing) so junctions read cleanly.
#
# You need just two things: a **road-class column** (default `highway`) and **line geometry**.

# %%
import pathlib
import geopandas as gpd
import roadstyle as rs

# A GeoDataFrame of road edges. roadstyle only needs a *road-class* column (default "highway")
# and line geometry in any CRS — it reprojects to web coordinates (EPSG:4326) for you.
edges = gpd.read_file(pathlib.Path("data") / "sodermalm_edges.gpkg")
print(f"{len(edges):,} edges, CRS {edges.crs}")
edges[[c for c in edges.columns if c != edges.geometry.name]].head(3)
# Out:
# 4,563 edges, CRS EPSG:4326
# ERROR 1: PROJ: proj_create_from_database: Open of /home/kaveh/miniconda3/envs/roadstyle/share/proj failed
#                edge_id   osm_id    edge_ref      highway           name  \
# 0  6379011699359957301  4080398  4080398#1f  residential     Nackagatan
# 1  4910696379820034244  4080398  4080398#3f  residential     Nackagatan
# 2  6981489206416339981  4080984  4080984#2f  residential  Högalidsgatan
#
#    lanes  oneway  maxspeed_kmh   length_m tunnel bridge layer
# 0      1   False          30.0  61.872971    NaN    NaN   NaN
# 1      1   False          30.0  34.481152    NaN    NaN   NaN
# 2      1   False          30.0  34.356903    NaN    NaN   NaN

# %% [markdown]
# ## Render with one call
# `render_edges` returns a self-contained **web map** (MapLibre) — in Jupyter the last expression displays it inline; `.save("map.html")` writes a file that opens offline. (`backend="folium"` and `backend="lonboard"` are the alternatives.)
#
# > If a map shows *"Make this Notebook Trusted to load map"*: Jupyter blocks stored outputs it didn't produce — use **File → Trust Notebook**, or just run the cells (running yourself always trusts the result).

# %%
m = rs.render_edges(edges, basemap="dark_matter", compress=True)   # high-saturation palette on a dark base map
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;&lt;html&gt;&lt;head&gt;&lt;meta charset=&quot;utf-8&quot;/&gt;
# &lt;title&gt;roadstyle&lt;/title&gt;
# &lt;meta name=&quot;viewport&quot; content=&quot;initial-scale=1,maximum-scale=1,user-scalable=no&quot;/&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maplibre-gl@3.6.2/dist/maplibre-gl.css&quot;/&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/maplibre-gl@3.6.2/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
# &lt;style&gt;html,body{margin:0;height:100%}#map{position:absolute;inset:0}
# .bm-ctrl{position:absolute;top:10px;left:10px;z-index:2;background:#fff;border-radius:5px;
# box-shadow:0 1px 4px rgba(0,0,0,.3);padding:4px 7px;font:13px system-ui,sans-serif}
# .bm-ctrl select{font:inherit;border:0;background:transparent;cursor:pointer;outline:none}
# .flt-ctrl{position:absolute;top:48px;left:10px;z-index:2;background:#fff;border-radius:5px;
# ...

# %% [markdown]
# ## Palettes & base maps
# Two palettes — `highsat` (high-contrast) and `carto` (classic OSM) — pick the road colours; `basemap=` picks the backdrop (any key in `rs.BASEMAPS`, default `voyager` from the settings file).

# %%
rs.render_edges(edges, palette="carto", compress=True)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;&lt;html&gt;&lt;head&gt;&lt;meta charset=&quot;utf-8&quot;/&gt;
# &lt;title&gt;roadstyle&lt;/title&gt;
# &lt;meta name=&quot;viewport&quot; content=&quot;initial-scale=1,maximum-scale=1,user-scalable=no&quot;/&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maplibre-gl@3.6.2/dist/maplibre-gl.css&quot;/&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/maplibre-gl@3.6.2/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
# &lt;style&gt;html,body{margin:0;height:100%}#map{position:absolute;inset:0}
# .bm-ctrl{position:absolute;top:10px;left:10px;z-index:2;background:#fff;border-radius:5px;
# box-shadow:0 1px 4px rgba(0,0,0,.3);padding:4px 7px;font:13px system-ui,sans-serif}
# .bm-ctrl select{font:inherit;border:0;background:transparent;cursor:pointer;outline:none}
# .flt-ctrl{position:absolute;top:48px;left:10px;z-index:2;background:#fff;border-radius:5px;
# ...

# %% [markdown]
# ## Save to a standalone HTML file
# `.save()` writes a self-contained page you can open in any browser or drop into a site.

# %%
# Maps/files in this guide are written to ./output/ (git-ignored), so nothing clutters the repo.
out = pathlib.Path("output"); out.mkdir(exist_ok=True)
rs.render_edges(edges, basemap="dark_matter", compress=True).save(out / "quickstart.html")
print("wrote", out / "quickstart.html")
# Out:
# wrote output/quickstart.html

# %% [markdown]
# That's the whole loop: **load → `render_edges` → `.save`**. The next notebooks add data-driven colour, filtering, and web embedding.

# %% [markdown]
# ## 3D view
# `view_3d=True` opens the map tilted and renders bridges as ramped, semi-transparent 3D decks (hover one — the whole bridge lights up; the on-map **2D/3D** button switches the camera). All knobs live in the `camera` / `bridge_decks` settings blocks.

# %%
rs.render_edges(edges, basemap="dark_matter", view_3d=True, compress=True)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;&lt;html&gt;&lt;head&gt;&lt;meta charset=&quot;utf-8&quot;/&gt;
# &lt;title&gt;roadstyle&lt;/title&gt;
# &lt;meta name=&quot;viewport&quot; content=&quot;initial-scale=1,maximum-scale=1,user-scalable=no&quot;/&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maplibre-gl@3.6.2/dist/maplibre-gl.css&quot;/&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/maplibre-gl@3.6.2/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
# &lt;style&gt;html,body{margin:0;height:100%}#map{position:absolute;inset:0}
# .bm-ctrl{position:absolute;top:10px;left:10px;z-index:2;background:#fff;border-radius:5px;
# box-shadow:0 1px 4px rgba(0,0,0,.3);padding:4px 7px;font:13px system-ui,sans-serif}
# .bm-ctrl select{font:inherit;border:0;background:transparent;cursor:pointer;outline:none}
# .flt-ctrl{position:absolute;top:48px;left:10px;z-index:2;background:#fff;border-radius:5px;
# ...
